# %% [markdown]
# ## 引子

# %% [markdown]
# > Python的特点是良好的一致性
# 双下划线方法使得Python的对象实现和所支持的语言架构交互：
# >> - 迭代
# - 集合类
# - 属性访问
# - 运算符重载
# - 函数和方法的调用
# - 对象的创建和销毁
# - 字符串表示形式和格式化
# - 管理上下文

# %% [markdown]
# ### 1.Python 风格的纸牌

# %%
import collections

Card = collections.namedtuple('Card',['rank','suit'])

class FrenchDeck:
    

    ranks = [str(n) for n in range(2,11)] + list('JQKA')
    suits = 'spades diamonds clubs hearts'.split()

    def __init__(self):
        self._cards = [Card(rank, suit) for suit in self.suits
                                        for rank in self.ranks]

    def __len__(self):
        return len(self._cards)

    def __getitem__(self, position):   # intersting
        return self._cards[position]

# %%
beer_card = Card('7', 'diamonds')
beer_card
# Out:
# Card(rank='7', suit='diamonds')

# %%
deck = FrenchDeck()
len(deck)
# Out:
# 52

# %%
deck[0]
# Out:
# Card(rank='2', suit='spades')

# %%
deck[-1]
# Out:
# Card(rank='A', suit='hearts')

# %%
deck[:3]
# Out:
# [Card(rank='2', suit='spades'),
#  Card(rank='3', suit='spades'),
#  Card(rank='4', suit='spades')]

# %%
deck[12::13]
# Out:
# [Card(rank='A', suit='spades'),
#  Card(rank='A', suit='diamonds'),
#  Card(rank='A', suit='clubs'),
#  Card(rank='A', suit='hearts')]

# %%
Card('Q', 'hearts') in deck
# Out:
# True

# %%
Card('Z', 'clubs') in deck
# Out:
# False

# %%
# 各种迭代
for card in deck:  # doctest: +ELLIPSIS
    print(card)
    
for card in reversed(deck):  # doctest: +ELLIPSIS
    print(card)

for n, card in enumerate(deck, 1):  # doctest: +ELLIPSIS
    print(n, card)

# %%
from random import choice

choice(deck)
# Out:
# Card(rank='5', suit='clubs')

# %%
choice(deck)
# Out:
# Card(rank='2', suit='spades')

# %%
# 生序排序
suit_values = dict(spades=3, hearts=2, diamonds=1, clubs=0)
def spades_high(card):
    rank_value = FrenchDeck.ranks.index(card.rank)
    return rank_value * len(suit_values) + suit_values[card.suit]

# %%
spades_high(Card('2', 'clubs'))
# Out:
# 0

# %%
spades_high(Card('A', 'spades'))
# Out:
# 51

# %%
for card in sorted(deck, key=spades_high):  # doctest: +ELLIPSIS
    print(card)

# %% [markdown]
# > __getitem__和 __len__两个特殊方法让FrenchDeck就跟Python自有的序列数据类型一样

# %% [markdown]
# ### 2.如何使用特殊方法

# %% [markdown]
# >特殊方法的存在是为了被Python解释器自己调用
#
# >通常通过内置函数来使用特殊方法

# %% [markdown]
# #### 一个二维向量类
# - \_\_repr\_\_
# - \_\_abs\_\_
# - \_\_add\_\_
# - \_\_mul\_\_

# %%
from math import hypot

class Vector:

    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y

    def __repr__(self):
        return 'Vector(%r, %r)' % (self.x, self.y)

    def __abs__(self):
        return hypot(self.x, self.y)  #返回欧几里得距离

    def __bool__(self):
        return bool(abs(self))

    def __add__(self, other):
        x = self.x + other.x
        y = self.y + other.y
        return Vector(x, y)

    def __mul__(self, scalar):
        return Vector(self.x * scalar, self.y * scalar)

# %%
v1 = Vector(2,4)
v2 = Vector(2,1)
v1+v2
# Out:
# Vector(4, 5)

# %%
v =Vector(3,4)   # abs
abs(v)
# Out:
# 5.0

# %%
v*3   # mul
# Out:
# Vector(9, 12)

# %%
abs(v*3)  # abs
# Out:
# 15.0

# %%
print(v) # print
# Out:
# Vector(3, 4)

# %% [markdown]
# > 如果一个对象没有 \_\_str\_\_函数，Python需要调用时解释器会用\_\_repr\_\_作为替代

# %% [markdown]
# 运算符无关的特殊方法 | 方法名
# ------- | -------
# 字符串/字节序列表示形式 |  \_\_repr\_\_  \_\_str\_\_  \_\_format\_\_  \_\_bytes\_\_
# 数值转换| \_\_abs\_\_ \_\_bool\_\_ \_\_complex\_\_ \_\_int\_\_ \_\_float\_\_ \_\_hash\_\_ \_\_index\_\_
# 集合模拟|\_\_len\_\_ \_\_getitem\_\_ \_\_setitem\_\_ \_\_delitem\_\_ \_\_contains\_\_
# 迭代枚举|\_\_iter\_\_ \_\_reversed\_\_ \_\_next\_\_
# 调用模拟|\_\_call\_\_
# 上下文管理| \_\_enter\_\_ \_\_exit\_\_
# 实例创建和销毁|\_\_new\_\_ \_\_init\_\_ \_\_del\_\_
# 属性管理|\_\_getattr\_\_ \_\_getattribute\_\_ \_\_setattr\_\_ \_\_delattr\_\_ \_\_dir\_\_
# 属性描述符|\_\_set\_\_ \_\_get\_\_ \_\_delete\_\_
# 类相关服务|\_\_prepare\_\_ \_\_instancecheck\_\_ \_\_subclasscheck\_\_

# %% [markdown]
# 运算符相关的特殊方法 | 方法名和对应的运算符
# ---- | ----
# 一元运算符|  \_\_neg\_\_ -, \_\_pos\_\_ +, \_\_abs\_\_ abs()
# 多元比较运算符| \_\_lt\_\_ <, \_\_le\_\_ <=, \_\_eq\_\_ ==, \_\_ne\_\_ !=, \_\_gt\_\_ >, \_\_ge\_\_ >=
# 算数运算符1|\_\_add\_\_ +, \_\_sub\_\_ -, \_\_mul\_\_ *, \_\_truediv\_\_ /, \_\_floordiv\_\_ //
# 算数运算符2|\_\_mod\_\_ %, \_\_divmod\_\_ divmod( ), \_\_pow\_\_ pow( ), \_\_round\_\_ round( )
# 反向算数运算符|\_\_radd\_\_ \_\_rsub\_\_ \_\_rmul\_\_ \_\_rtruediv\_\_ \_\_rfloordiv\_\_ \_\_rmod\_\_ \_\_rdivmod\_\_
# 增量赋值算数运算符|\_\_iadd\_\_ \_\_isub\_\_ \_\_imul\_\_ \_\_itruediv\_\_ \_\_ifloordiv\_\_ \_\_imod\_\_ \_\_ipow\_\_
# 位运算符| \_\_invert\_\_ ~, \_\_lshift\_\_ <<, \_\_rshift\_\_ >>, \_\_and\_\_ &, \_\_or\_\_ |, \_\_xor\_\_ ^
# 反向位运算符|\_\_rlshift\_\_ \_\_rrshift\_\_ \_\_rand\_\_ \_\_rxor\_\_ \_\_ror\_\_
# 增量赋值位运算符|\_\_ilshift\_\_ \_\_irshift\_\_ \_\_iand\_\_ \_\_ixor\_\_ \_\_ior\_\_

# %% [markdown]
# > len abs不是普通方法(为了效率)
#
# > 不能让特例特殊到开始破坏既定规则
